# %%
# !pip install -q transformers

# %% [markdown]
# # **MADE BY ANUJ BAGHEL**

# %% [markdown]
# # **Youtube video text summerizer by**![279218057_713923679956122_4086625164762279978_n.jpg](data:image/jpeg;base64,...) **Anuj Baghel**

# %%
# !pip install -q youtube_transcript_api

# %%
from transformers import pipeline
from youtube_transcript_api import YouTubeTranscriptApi

# %%
youtube_video = "https://www.youtube.com/watch?v=qeJhIBmiYdQ"

# %%
video_id = youtube_video.split("=")[1]

# %%
video_id
# Out:
# 'qeJhIBmiYdQ'

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(video_id)

# %%
YouTubeTranscriptApi.get_transcript(video_id)
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# %%
transcript[0:5]
# Out:
# [{'text': 'ladies and Gentlemen The Honorable prime',
#   'start': 0.24,
#   'duration': 6.32},
#  {'text': 'minister of India SRI Narendra Modi',
#   'start': 3.36,
#   'duration': 10.62},
#  {'text': '[Applause]', 'start': 6.56, 'duration': 7.42},
#  {'text': 'my colleague in the union cabinet',
#   'start': 20.22,
#   'duration': 6.299},
#  {'text': 'Shah', 'start': 23.76, 'duration': 5.72}]

# %%
result = ""
for i in transcript:
    result += ' ' + i['text']
#print(result)
print(len(result))
# Out:
# 7870

# %%
summarizer = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
num_iters = int(len(result)/1000)
summarized_text = []
for i in range(0, num_iters + 1):
  start = 0
  start = i * 1000
  end = (i + 1) * 1000
  print("input text \n" + result[start:end])
  out = summarizer(result[start:end])
  out = out[0]
  out = out['summary_text']
  print("Summarized text\n"+out)
  summarized_text.append(out)

#print(summarized_text)
# Out:
# input text
#  ladies and Gentlemen The Honorable prime minister of India SRI Narendra Modi [Applause] my colleague in the union cabinet Shah interval president interval secretary gender she organ stock director of CBI iswal distinguished delegates and participants I extend a warm welcome to everyone [Music] for the 98th internet assembly it is a great to have you here at a time that is significant for both India and the Interpol India is celebrating 75 years of Independence in 2022 it is a celebration of our people culture and achievements it is a time for looking back at where we came from and also for looking ahead at where we want to go the Interpol is also approaching a history milestone in 2023 interpore will be celebrating 100 Years of founding this is a good time to rejoice and reflect lump from setbacks celebrate victories and then look to the future with hope friends the concept of Interpol finds a connect with various aspects of Indian philosophy the motto of the interval is connecting po
# Summarized text
#  India is celebrating 75 years of Independence in 2022 it is a celebration of our people culture and achievements . The concept of Interpol finds a connect with various aspects of Indian philosophy the motto of the interval is connecting po . Interpol is also approaching a history milestone in 2023 interpore will be celebrating 100 Years of founding .
# input text
# lice for a safer world many of you may have heard of The Vedas as one of the world's oldest scriptures in Veda says it means let Noble thoughts come from all directions this is a call for Universal cooperation to make the world a better place there is a unique Global Outlook in India it's all this is why India is one of the top contributors in sending brave men and women the United Nations peacekeeping operations even before our own independence we made sacrifices to make the world a better place thousands of Indians fought and died in the world wars from climate targets to covet vaccines India has shown willingness to take the lead in any kind of crisis and now at a time when Nations and societies are becoming inward looking India called for more not less International cooperation Global cooperation for local welfare is our call friends the philosophy of law enforcement is best explained by chanakya the ancient Indian philosopher Allah it means the material and spiritual welfare of a
# Summarized text
